# %% [markdown]
# <a href="https://colab.research.google.com/github/vikhyatt/DS-Assignments/blob/main/Copy_of_%5BCS753%5D_Assignment_2_2024_INFERENCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Necessary installations
# !pip install transformers[torch]
# !pip install datasets
# !pip install evaluate
# !pip install jiwer
# !pip install -U openai-whisper
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.2.1+cu121)
# Collecting accelerate>=0.21.0 (from transformers[torch])
#   Downloading accelerate-0.29.2-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.4/297.4 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->transformers[torch])
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->transformers[torch])
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->transformers[torch])
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->transformers[torch])
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->transformers[torch])
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->transformers[torch])
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->transformers[torch])
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch])
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->transformers[torch]) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.29.2 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 24.2 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-2.18.0 dill-0.3.8 multiprocess-0.70.16 xxhash-3.4.1
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.25.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.0)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.13.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.9.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Installing collected packages: responses, evaluate
# Successfully installed evaluate-0.4.1 responses-0.18.0
# Collecting jiwer
#   Downloading jiwer-3.0.3-py3-none-any.whl (21 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 15.8 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.3 rapidfuzz-3.8.1
# Collecting openai-whisper
#   Downloading openai-whisper-20231117.tar.gz (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (2.2.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (0.58.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (1.25.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (2.2.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (4.66.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (10.1.0)
# Collecting tiktoken (from openai-whisper)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 29.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton<3,>=2.0.0->openai-whisper) (3.13.4)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper) (0.41.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper) (2.31.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->openai-whisper) (12.4.127)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper) (1.3.0)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=801358 sha256=309727cd41d7711f428b2515462bc5468527643776c119bec92b83f9b85da1df
#   Stored in directory: /root/.cache/pip/wheels/d0/85/e1/9361b4cbea7dd4b7f6702fa4c3afc94877952eeb2b62f45f56
# Successfully built openai-whisper
# Installing collected packages: tiktoken, openai-whisper
# Successfully installed openai-whisper-20231117 tiktoken-0.6.0

# %% [markdown]
# ## Dataset preparation

# %%
# Download dataset and unzip
# !wget https://www.cse.iitb.ac.in/~pjyothi/cs753/dataset.zip
# !unzip dataset.zip
# Out:
# --2024-04-14 14:00:12--  https://www.cse.iitb.ac.in/~pjyothi/cs753/dataset.zip
# Resolving www.cse.iitb.ac.in (www.cse.iitb.ac.in)... 103.21.127.134
# Connecting to www.cse.iitb.ac.in (www.cse.iitb.ac.in)|103.21.127.134|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 139124027 (133M) [application/zip]
# Saving to: ‘dataset.zip’
#
# dataset.zip         100%[===================>] 132.68M  4.54MB/s    in 20s
#
# 2024-04-14 14:00:34 (6.71 MB/s) - ‘dataset.zip’ saved [139124027/139124027]
#
# Archive:  dataset.zip
#    creating: CodeSwitched_Data/
#   inflating: CodeSwitched_Data/valid.json
#   inflating: CodeSwitched_Data/test_blind_no_transcript.json
#   inflating: CodeSwitched_Data/train.json
#   inflating: CodeSwitched_Data/test_blind.json
#    creating: CodeSwitched_Data/audio/
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003320.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009337.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004786.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008866.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005854.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014034.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005233.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013503.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004297.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012838.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009392.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014112.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009244.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014331.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014079.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011877.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006430.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001527.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002605.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009842.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001926.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001060.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012282.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005216.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004492.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005526.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013786.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005257.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009367.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011868.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006095.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005271.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013698.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011053.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011973.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005547.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009191.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000699.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003275.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008224.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005098.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002354.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011885.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003653.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009016.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008169.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010896.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005777.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010595.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011580.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002777.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006996.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001098.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008901.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012636.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013731.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010356.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013468.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012497.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010638.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010213.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004427.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003289.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004480.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012290.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012655.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003381.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000367.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009284.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006634.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008529.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008355.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006381.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011491.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006606.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002038.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002604.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011988.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013705.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005986.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012171.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012158.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009362.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014308.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002374.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012952.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014043.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009066.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004151.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000369.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011523.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007526.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011551.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007044.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013526.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001490.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007595.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008027.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013556.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014295.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006134.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005483.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013538.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001023.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003369.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007984.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012755.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003119.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008752.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007148.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010242.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000320.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005878.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008678.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009144.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004318.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007911.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005239.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000605.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005824.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010202.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001802.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012802.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008297.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012947.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002440.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007364.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007047.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013446.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004855.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009035.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001171.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005123.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002402.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006993.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001138.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006269.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001226.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003933.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005240.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006130.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002562.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009844.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004533.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010261.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000678.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010396.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012433.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011587.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001399.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013727.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004042.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005027.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012960.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005317.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013440.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004512.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008520.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003079.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006858.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008246.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009306.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005406.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008969.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000624.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009090.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005815.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001783.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007508.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003114.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000674.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007159.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012627.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008338.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002373.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005863.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012879.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009220.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004362.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000623.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011380.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014233.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010284.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011126.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012917.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006215.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000558.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009043.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005619.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000429.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000371.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010147.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007614.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008399.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009417.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006382.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010702.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008313.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001829.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001743.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000386.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003882.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011505.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013415.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005644.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004519.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010400.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004341.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007914.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010013.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013714.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011834.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003717.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003029.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005816.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005101.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001989.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006688.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006262.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011526.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006402.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002167.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008215.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003083.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013524.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007490.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007757.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003234.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006230.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013412.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006142.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007025.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013471.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012311.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004865.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012107.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010110.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003760.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009843.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006398.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011384.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000863.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002054.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007169.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013846.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011041.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007356.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006121.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011849.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007907.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006857.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003590.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003956.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008318.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014383.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002335.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001848.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001810.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005849.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005956.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005500.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012939.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007912.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004448.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012707.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014106.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003068.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011592.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010164.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009058.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008808.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014109.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006039.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005753.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006784.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004441.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001203.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012224.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001021.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002457.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005201.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004772.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008236.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012576.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001140.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004149.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014002.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005536.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000479.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008845.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012894.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004433.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001356.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014016.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003736.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000879.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007054.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010382.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008144.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001125.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010369.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002185.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004750.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013768.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011377.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010571.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007903.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002540.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009051.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000341.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000817.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000290.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008205.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004387.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005299.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005942.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003341.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012156.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008879.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001901.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012272.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010380.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011097.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010313.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010230.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003714.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012901.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010371.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008176.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000409.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012252.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002718.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005066.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000436.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004777.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010696.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013587.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008954.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000548.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008243.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012648.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009376.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000456.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013401.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003874.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007274.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011995.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000862.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003926.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007145.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001534.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004304.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010449.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012614.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004822.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006699.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001192.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014084.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006069.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009372.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008360.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008308.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001762.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010188.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004019.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008916.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006150.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007024.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002546.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004436.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001376.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001202.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012875.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001049.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004148.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010300.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004440.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006671.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000806.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001328.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001775.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012039.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006838.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002568.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014292.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010670.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000636.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002580.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001828.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001589.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008911.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009082.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013499.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012637.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013011.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013579.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000911.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001818.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007888.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004077.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008671.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011561.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001347.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004748.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008372.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011511.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000886.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010627.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009046.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003265.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001169.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010281.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001570.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012197.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012913.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010389.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014396.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012408.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005485.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007072.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012008.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003057.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004495.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012186.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002905.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014372.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008686.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003608.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007068.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006885.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002387.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013399.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002031.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006495.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002538.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008816.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010989.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005057.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005710.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004140.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001473.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007890.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005430.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002550.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007379.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003497.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007602.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009366.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007504.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010287.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002359.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001375.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012688.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007893.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006698.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004024.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000335.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003620.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006081.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011433.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000861.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013584.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012176.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014012.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008582.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013486.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011436.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001143.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001230.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012548.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007649.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010278.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011620.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004487.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011977.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011895.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001902.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005283.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003271.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005012.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013948.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011401.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000767.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010296.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003280.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010584.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008388.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011931.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002896.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004157.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010680.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008365.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012247.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002093.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012089.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006753.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002092.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006145.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012782.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008674.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003064.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013531.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007598.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009318.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005222.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012194.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013422.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005700.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007596.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00014318.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004615.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003552.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000573.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006096.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009210.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011886.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012261.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009907.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012744.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012022.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001020.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003667.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005794.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010054.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001515.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000347.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002552.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006107.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009857.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006956.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004491.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012816.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008932.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011968.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012826.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006282.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008408.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004084.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012916.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004079.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010424.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008974.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00003279.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011205.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008320.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010898.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011039.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004264.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001817.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004127.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005879.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010289.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008813.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005015.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010995.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011490.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001258.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000828.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013986.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007871.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011023.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008980.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004973.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005733.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001097.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001264.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004717.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006164.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000769.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007039.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000724.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012520.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005433.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002111.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001016.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001710.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00006032.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007527.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007644.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010623.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012928.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005230.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009822.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012605.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012848.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010904.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009329.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001752.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00009418.wav
#   inflating: CodeSwitched_Data/audio/.DS_Store
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00010316.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00007496.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005811.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000597.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00002483.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001289.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005801.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001117.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001123.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008268.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012542.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001245.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00013362.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00008679.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005681.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004167.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00004380.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00012513.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00011101.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00001525.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00000735.wav
#   inflating: CodeSwitched_Data/audio/SHA1P_utt00005495.wav
#   inflating: CodeSwitched_Data/transcriptions.csv
#   inflating: CodeSwitched_Data/test.json
#   inflating: CodeSwitched_Data/.DS_Store
#    creating: CodeSwitched_Data/.ipynb_checkpoints/

# %%
import datasets
from datasets import load_dataset

from transformers import WhisperFeatureExtractor
from transformers import WhisperTokenizer
from transformers import WhisperProcessor

import torch

from dataclasses import dataclass
from typing import Any, Dict, List, Union, Optional,Tuple

from transformers import Seq2SeqTrainingArguments
from transformers import Seq2SeqTrainer
from transformers import WhisperForConditionalGeneration

# %%
# Load json files for test split
data_files = {
    "test": "./CodeSwitched_Data/test.json"
}
dataset = load_dataset("json", data_files=data_files)

# Update the audio paths to include appropriate folder-name
def prepend_folder_name(row):
    row["audio"] = 'CodeSwitched_Data/' + row["audio"]
    return row
for key in dataset:
    dataset[key] = dataset[key].map(prepend_folder_name)

# Cast columns to appropriate features
features = datasets.Features(
    {
        "id": datasets.Value("string"),
        "transcription": datasets.Value("string"),
        "audio": datasets.Audio(sampling_rate=16000),
    }
)
dataset = dataset.map(features.encode_example, features=features)
# Out:
# Generating test split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/61 [00:00<?, ? examples/s]
# Map:   0%|          | 0/61 [00:00<?, ? examples/s]

# %%
# Load necessary processors
feature_extractor = WhisperFeatureExtractor.from_pretrained("openai/whisper-small")
tokenizer = WhisperTokenizer.from_pretrained("openai/whisper-small", language="Hindi", task="transcribe")
processor = WhisperProcessor.from_pretrained("openai/whisper-small", language="Hindi", task="transcribe")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.19k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def prepare_dataset(batch):
    # load and resample audio data from 48 to 16kHz
    audio = batch["audio"]
    # encode target text to label ids
    batch["labels"] = tokenizer(batch["transcription"]).input_ids
    return batch
dataset = dataset.map(prepare_dataset, num_proc=2)
# Out:
# /usr/local/lib/python3.10/dist-packages/multiprocess/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Map (num_proc=2):   0%|          | 0/61 [00:00<?, ? examples/s]

# %% [markdown]
# ## Task 2.1: Zero shot whisper greedy decoding
#
# > In this task, you will run a standard greedy decoding of the test utterances using the pretrained Whisper small model.

# %%
import json
import numpy as np
from evaluate import load
import whisper
import tqdm

wer = load("wer")
cer = load("cer")

def inferencer(json_file_path, model, dataset):
    """
    Perform inference on every example within `dataset` using `model` and save it in `json_file_path`.
    """

    predictions = []
    ground_truths = []
    to_json = []
    for item in tqdm.tqdm(dataset):
        ground_truth = item['transcription']
        prediction = model.transcribe(audio = torch.tensor(item['audio']['array'].astype(np.float32)), language="hi")['text']

        ground_truths.append(ground_truth)
        predictions.append(prediction)

        to_json.append({
            'id': item['id'],
            'ground_truth': ground_truth,
            'prediction': prediction
        })

    cer_ = cer.compute(predictions=predictions, references=ground_truths)
    wer_ = wer.compute(predictions=predictions, references=ground_truths)

    to_json = [{'cer':cer_, 'wer': wer_}] + to_json

    # Write updated data back to JSON file
    with open(json_file_path, 'w') as json_file:
        json.dump(to_json, json_file, indent=4)
# Out:
# Downloading builder script:   0%|          | 0.00/4.49k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/5.60k [00:00<?, ?B/s]

# %%
model = whisper.load_model("small")
json_file_path = "./zero_shot_whisper.json"
inferencer(json_file_path, model, dataset['test'])
# Out:
# 100%|███████████████████████████████████████| 461M/461M [00:05<00:00, 95.2MiB/s]
# 100%|██████████| 61/61 [09:44<00:00,  9.58s/it]

# %%
# !head -n 5 ./zero_shot_whisper.json
# Out:
# [
#     {
#         "cer": 0.6892015110069037,
#         "wer": 0.8800468110005851
#     },

# %%
# !wget https://www.cse.iitb.ac.in/~pjyothi/cs753/whisper-small-finetuned.pt
# Out:
# --2024-04-14 14:11:55--  https://www.cse.iitb.ac.in/~pjyothi/cs753/whisper-small-finetuned.pt
# Resolving www.cse.iitb.ac.in (www.cse.iitb.ac.in)... 103.21.127.134
# Connecting to www.cse.iitb.ac.in (www.cse.iitb.ac.in)|103.21.127.134|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 967102564 (922M)
# Saving to: ‘whisper-small-finetuned.pt’
#
# whisper-small-finet 100%[===================>] 922.30M  12.8MB/s    in 1m 43s
#
# 2024-04-14 14:13:41 (8.91 MB/s) - ‘whisper-small-finetuned.pt’ saved [967102564/967102564]

# %%
model = whisper.load_model("/content/whisper-small-finetuned.pt")
json_file_path = "./greedy_whisper.json"
inferencer(json_file_path, model, dataset['test'])
# Out:
# 100%|██████████| 61/61 [07:58<00:00,  7.84s/it]

# %%
# !head -n 5 ./greedy_whisper.json
# Out:
# [
#     {
#         "cer": 0.47036602839650904,
#         "wer": 0.6869514335868929
#     },

# %% [markdown]
# ## Task 2.2: Constrained Filtering-based Greedy Decoding

# %%
from whisper.decoding import DecodingOptions, DecodingResult, DecodingTask, GreedyDecoder, TokenDecoder, Inference
from dataclasses import dataclass, field, replace
from typing import TYPE_CHECKING, Dict, Iterable, List, Optional, Sequence, Tuple, Union

import numpy as np
import torch.nn.functional as F
from torch import Tensor
from torch.distributions import Categorical

from whisper.audio import CHUNK_LENGTH
from whisper.tokenizer import Tokenizer, get_tokenizer
from whisper.utils import compression_ratio

if TYPE_CHECKING:
    from whisper.model import Whisper

# %%
"""
TODO: Define helper functions to perform constrained filtering here, if needed.
"""
import torch.nn.functional as F

def sample_batch(logits: torch.Tensor, N: int = 10, p: float = 0.9) -> torch.Tensor:
    """
      Sample the next best token for every example within a batch, using constrained filtering.
    """
    # TODO: Implement this function as follows:
    #   For every example within the batch:
    #       1. For tokens that do not satisfy the (N,p) constraints, update its value in `logits` to '-Infinity'.
    #       2. Convert the updated `logits` into a probability distribution.
    #       3. Finally, sample (https://pytorch.org/docs/stable/generated/torch.multinomial.html) from this probability distribution to obtain 1 token per example.
    # TODO: You can create any helper functions that sample_batch needs within this cell
    top_n_val, top_n_indices = torch.topk(logits, N)
    top_n_probs = F.softmax(top_n_val, dim=1)
    batches , vocab_size = logits.shape

    idx = 0
    cum_sum = 0
    batch_wise_idx = []
    for i in range(batches):
      for j in range(N):
        cum_sum += top_n_probs[i][j]
        idx = j

        if cum_sum > p:
          #idx = j-1
          if idx == -1:
            idx= 0
          break

      batch_wise_idx.append(idx)
      idx = 0
      cum_sum = 0

    sampled_tokens = []
    for i in range(batches):
      #print(batch_wise_idx[i])
      p_filtered_probs = top_n_probs[i, :batch_wise_idx[i]+1]
      p_probs = F.softmax(p_filtered_probs, dim = 0)
      sampled_idx = torch.multinomial(p_probs, 1)[0]
      sampled_tokens.append(top_n_indices[i][sampled_idx])

    #print(sampled_tokens, logits.shape)
    return torch.tensor(sampled_tokens).cuda()

# %%
import os
import traceback
import warnings

from whisper.audio import (
    FRAMES_PER_SECOND,
    HOP_LENGTH,
    N_FRAMES,
    N_SAMPLES,
    SAMPLE_RATE,
    log_mel_spectrogram,
    pad_or_trim,
)
from whisper.tokenizer import LANGUAGES, TO_LANGUAGE_CODE
from whisper.utils import (
    exact_div,
    format_timestamp,
    get_writer,
    make_safe,
    optional_float,
    optional_int,
    str2bool,
)

# %%
tokenizer_list = []

# %%
"""
Custom classes to integrate constrained filtering within greedy decoding.
"""

class CustomGreedyDecoder(GreedyDecoder):
    """
    Updates the existing `GreedyDecoder` class form whisper to use constrained_filtering
    """
    def __init__(self, temperature: float, eot: int):
        super().__init__(temperature, eot)

    def update(
        self, tokens: Tensor, logits: Tensor, sum_logprobs: Tensor
    ) -> Tuple[Tensor, bool]:
        """
        Updates the token list `tokens` to add a next best token using constrained_filtering
        """
        # TODO: sample_batch should be modified to implement constrained_filtering
        next_tokens = sample_batch(logits)

        logprobs = F.log_softmax(logits.float(), dim=-1)
        current_logprobs = logprobs[torch.arange(logprobs.shape[0]), next_tokens]
        # sum_logprobs += current_logprobs * (tokens[:, -1] != self.eot)

        next_tokens[tokens[:, -1] == self.eot] = self.eot
        tokens = torch.cat([tokens, next_tokens[:, None]], dim=-1)

        completed = (tokens[:, -1] == self.eot).all()
        return tokens, completed

class CustomDecodingTask(DecodingTask):
    """
    Updates the existing `DecodingTask` class form whisper to incorporate constrained_filtering
    """
    def __init__(self, model: "Whisper", options: DecodingOptions):
        super().__init__(model,options)
        self.decoder = CustomGreedyDecoder(
            self.options.temperature, self.tokenizer.eot
        )
@torch.no_grad()
def custom_decode(
    model: torch.nn.Module,
    mel: torch.Tensor,
    options: DecodingOptions = DecodingOptions(),

    **kwargs,
) -> Union[DecodingResult, List[DecodingResult]]:
    """
    decode function to perform constrained_filtering based greedy decoding
    """
    single = mel.ndim
    if single == 2:
        mel = mel.unsqueeze(0)

    if kwargs:
        options = replace(options, **kwargs)

    result = CustomDecodingTask(model, options).run(mel)

    return result[0] if single else result

def custom_transcribe(
    model: "Whisper",
    audio: Union[str, np.ndarray, torch.Tensor],
    *,
    compression_ratio_threshold: Optional[float] = 2.4,
    logprob_threshold: Optional[float] = -1.0,
    condition_on_previous_text: bool = True,
    prepend_punctuations: str = "\"'“¿([{-",
    append_punctuations: str = "\"'.。,，!！?？:：”)]}、",
    **decode_options,
):
    dtype = torch.float16 if decode_options.get("fp16", True) else torch.float32
    if model.device == torch.device("cpu"):
        if torch.cuda.is_available():
            warnings.warn("Performing inference on CPU when CUDA is available")
        if dtype == torch.float16:
            warnings.warn("FP16 is not supported on CPU; using FP32 instead")
            dtype = torch.float32

    if dtype == torch.float32:
        decode_options["fp16"] = False

    # Pad 30-seconds of silence to the input audio, for slicing
    mel = log_mel_spectrogram(audio, model.dims.n_mels, padding=N_SAMPLES)
    content_frames = mel.shape[-1] - N_FRAMES

    language: str = decode_options["language"]
    task: str = decode_options.get("task", "transcribe")
    tokenizer = get_tokenizer(
        model.is_multilingual,
        num_languages=model.num_languages,
        language=language,
        task=task,
    )
    tokenizer_list.append(tokenizer)
    #print(tokenizer.decode([0, 1000, 192]))

    def decode_with_fallback(segment: torch.Tensor) -> DecodingResult:
        decode_result = None

        temp = 0.0
        kwargs = {**decode_options}
        kwargs.pop("best_of", None)

        options = DecodingOptions(**kwargs, temperature=temp)
        decode_result = custom_decode(model, segment, options)

        return decode_result

    seek = 0
    input_stride = exact_div(
        N_FRAMES, model.dims.n_audio_ctx
    )  # mel frames per output token: 2
    time_precision = (
        input_stride * HOP_LENGTH / SAMPLE_RATE
    )  # time per output token: 0.02 (seconds)
    all_tokens = []
    all_segments = []

    prompt_reset_since = 0
    initial_prompt_tokens = []

    def new_segment(
        *, start: float, end: float, tokens: torch.Tensor, result: DecodingResult
    ):
        tokens = tokens.tolist()
        text_tokens = [token for token in tokens if token < tokenizer.eot]
        return {
            "seek": seek,
            "start": start,
            "end": end,
            "text": tokenizer.decode(text_tokens),
            "tokens": tokens,
            "temperature": result.temperature,
            "avg_logprob": result.avg_logprob,
            "compression_ratio": result.compression_ratio,
            "no_speech_prob": result.no_speech_prob,
        }

    last_speech_timestamp = 0.0
    while seek < content_frames:
        time_offset = float(seek * HOP_LENGTH / SAMPLE_RATE)
        mel_segment = mel[:, seek : seek + N_FRAMES]
        segment_size = min(N_FRAMES, content_frames - seek)
        segment_duration = segment_size * HOP_LENGTH / SAMPLE_RATE
        mel_segment = pad_or_trim(mel_segment, N_FRAMES).to(model.device).to(dtype)

        decode_options["prompt"] = all_tokens[prompt_reset_since:]
        result: DecodingResult = decode_with_fallback(mel_segment)
        tokens = torch.tensor(result.tokens)

        previous_seek = seek
        current_segments = []

        timestamp_tokens: torch.Tensor = tokens.ge(tokenizer.timestamp_begin)
        single_timestamp_ending = timestamp_tokens[-2:].tolist() == [False, True]

        consecutive = torch.where(timestamp_tokens[:-1] & timestamp_tokens[1:])[0]
        consecutive.add_(1)
        if len(consecutive) > 0:
            # if the output contains two consecutive timestamp tokens
            slices = consecutive.tolist()
            if single_timestamp_ending:
                slices.append(len(tokens))

            last_slice = 0
            for current_slice in slices:
                sliced_tokens = tokens[last_slice:current_slice]
                start_timestamp_pos = (
                    sliced_tokens[0].item() - tokenizer.timestamp_begin
                )
                end_timestamp_pos = (
                    sliced_tokens[-1].item() - tokenizer.timestamp_begin
                )
                current_segments.append(
                    new_segment(
                        start=time_offset + start_timestamp_pos * time_precision,
                        end=time_offset + end_timestamp_pos * time_precision,
                        tokens=sliced_tokens,
                        result=result,
                    )
                )
                last_slice = current_slice

            if single_timestamp_ending:
                # single timestamp at the end means no speech after the last timestamp.
                seek += segment_size
            else:
                # otherwise, ignore the unfinished segment and seek to the last timestamp
                last_timestamp_pos = (
                    tokens[last_slice - 1].item() - tokenizer.timestamp_begin
                )
                seek += last_timestamp_pos * input_stride
        else:
            duration = segment_duration
            timestamps = tokens[timestamp_tokens.nonzero().flatten()]
            if (
                len(timestamps) > 0
                and timestamps[-1].item() != tokenizer.timestamp_begin
            ):
                # no consecutive timestamps but it has a timestamp; use the last one.
                last_timestamp_pos = (
                    timestamps[-1].item() - tokenizer.timestamp_begin
                )
                duration = last_timestamp_pos * time_precision

            current_segments.append(
                new_segment(
                    start=time_offset,
                    end=time_offset + duration,
                    tokens=tokens,
                    result=result,
                )
            )
            seek += segment_size

        # if a segment is instantaneous or does not contain text, clear it
        for i, segment in enumerate(current_segments):
            if segment["start"] == segment["end"] or segment["text"].strip() == "":
                segment["text"] = ""
                segment["tokens"] = []
                segment["words"] = []

        all_segments.extend(
            [
                {"id": i, **segment}
                for i, segment in enumerate(
                    current_segments, start=len(all_segments)
                )
            ]
        )
        all_tokens.extend(
            [token for segment in current_segments for token in segment["tokens"]]
        )

        if not condition_on_previous_text or result.temperature > 0.5:
              # do not feed the prompt tokens if a high temperature was used
              prompt_reset_since = len(all_tokens)

    return dict(
        text=tokenizer.decode(all_tokens),
        segments=all_segments,
        language=language,
    )

# %%
import re

# Function to ignore tags in transcripts
def remove_tags(input_string):
    tag_pattern = re.compile(r'<[^>]+>')
    cleaned_string = re.sub(tag_pattern, '', input_string)
    return cleaned_string

def inferencer(json_file_path, model, dataset):

    predictions = []
    ground_truths = []
    to_json = []
    for item in tqdm.tqdm(dataset):
        ground_truth = item['transcription']
        prediction = custom_transcribe(model = model, audio = torch.tensor(item['audio']['array'].astype(np.float32)), language="hi")['text']

        ground_truths.append(remove_tags(ground_truth))
        predictions.append(remove_tags(prediction))

        to_json.append({
            'id': item['id'],
            'ground_truth': ground_truth,
            'prediction': prediction
        })

    cer_ = cer.compute(predictions=predictions, references=ground_truths)
    wer_ = wer.compute(predictions=predictions, references=ground_truths)

    to_json = [{'cer':cer_, 'wer': wer_}] + to_json

    # Write updated data back to JSON file
    with open(json_file_path, 'w') as json_file:
        json.dump(to_json, json_file, indent=4)

# %%
model = whisper.load_model("/content/whisper-small-finetuned.pt")
json_file_path = "./fine_tuned_whisper_with_constrained_filtering.json"
inferencer(json_file_path, model, dataset['test'])
# Out:
# 100%|██████████| 61/61 [03:17<00:00,  3.24s/it]

# %%
# !head -n 5 ./fine_tuned_whisper_with_constrained_filtering.json
# Out:
# [
#     {
#         "cer": 0.5262472319916635,
#         "wer": 0.7606787595084845
#     },

# %% [markdown]
# ## Task 2.3: Beam search Decoding using finetuned Whisper model

# %%
def inferencer(json_file_path, model, dataset, beam_size):
    """
    Perform inference on every example within `dataset` using `model` and save it in `json_file_path`.
    """

    predictions = []
    ground_truths = []
    to_json = []
    for item in tqdm.tqdm(dataset):
        ground_truth = item['transcription']
        prediction = model.transcribe(audio = torch.tensor(item['audio']['array'].astype(np.float32)), language="hi", beam_size=beam_size)['text']

        ground_truths.append(ground_truth)
        predictions.append(prediction)

        to_json.append({
            'id': item['id'],
            'ground_truth': ground_truth,
            'prediction': prediction
        })

    cer_ = cer.compute(predictions=predictions, references=ground_truths)
    wer_ = wer.compute(predictions=predictions, references=ground_truths)

    to_json = [{'cer':cer_, 'wer': wer_}] + to_json

    # Write updated data back to JSON file
    with open(json_file_path, 'w') as json_file:
        json.dump(to_json, json_file, indent=4)

# %%
json_file_path = "./fine_tuned_whisper_with_beam_search.json"
inferencer(json_file_path, model, dataset['test'], beam_size=3)
# Out:
# 100%|██████████| 61/61 [07:41<00:00,  7.56s/it]

# %%
# !head -n 5 ./fine_tuned_whisper_with_beam_search.json
# Out:
# [
#     {
#         "cer": 0.4871694672398072,
#         "wer": 0.7039204212990052
#     },

# %% [markdown]
# ## Task 2.4: Constrained Beam Search Decoding on finetuned Whisper model

# %%
nice_tokenizer = tokenizer_list[0]

# %%
from whisper.decoding import BeamSearchDecoder

"""
Custom classes to integrate constraints within beam search decoding.
"""
import string

class CustomBeamSearchDecoder(BeamSearchDecoder):
    """
    Updates the existing `BeamSearchDecoder` class form whisper to use constrained beam search
    """
    def __init__(
        self,
        beam_size: int,
        eot: int,
        inference: Inference,
        cutoff: int = 3,
        patience: Optional[float] = None,
    ):
        super().__init__(beam_size, eot, inference, patience)
        # TODO: Add any additional variables you need for constrained beam search here
        self.english_char = ' '.join(list(string.ascii_lowercase + string.ascii_uppercase))
        self.english_tokens = nice_tokenizer.encode(self.english_char)

    def classify_bank(self,tokens):
      #print(tokens, self.english_tokens)
      english_in_tok = set(tokens).intersection(set(self.english_tokens))

      if len(english_in_tok) == 0:
        return 0
      else:
        return 1

    def update(
        self, tokens: Tensor, logits: Tensor, sum_logprobs: Tensor
    ) -> Tuple[Tensor, bool]:
        """
        TODO: This is the main routine that implements constrained beam search
        Updates the token list `tokens` to add a next best token using constrained beam search
        Refer to https://github.com/openai/whisper/blob/main/whisper/decoding.py#L301-L404 for the original update function
        """

        if tokens.shape[0] % self.beam_size != 0:
            raise ValueError(f"{tokens.shape}[0] % {self.beam_size} != 0")

        n_audio = tokens.shape[0] // self.beam_size
        if self.finished_sequences is None:  # for the first update
            self.finished_sequences = [{} for _ in range(n_audio)]

        logprobs = F.log_softmax(logits.float(), dim=-1)
        next_tokens, source_indices, finished_sequences = [], [], []
        for i in range(n_audio):
            scores, sources, finished = {}, {}, {}
            bank_0  , bank_1 = {} , {}
            # STEP 1: calculate the cumulative log probabilities for possible candidates
            for j in range(self.beam_size):
                idx = i * self.beam_size + j
                prefix = tokens[idx].tolist()
                for logprob, token in zip(*logprobs[idx].topk(self.beam_size + 1)):
                    new_logprob = (sum_logprobs[idx] + logprob).item()
                    sequence = tuple(prefix  + [token.item()])
                    seq_bank = self.classify_bank(prefix + [token.item()])

                    if seq_bank:
                      bank_1[sequence] = new_logprob
                    else:
                      bank_0[sequence] = new_logprob

                    scores[sequence] = new_logprob
                    sources[sequence] = idx

            # STEP 2: rank the candidates and keep the top beam_size sequences for each audio
            saved = 0
            bank_1_sorted = sorted(bank_1, key=bank_1.get, reverse=True)
            if len(bank_1_sorted) > 0:
              bank_1_best_seq = bank_1_sorted[0]

              if bank_1_best_seq[-1] == self.eot:
                finished[bank_1_best_seq] = scores[bank_1_best_seq]
              else:
                sum_logprobs[len(next_tokens)] = scores[bank_1_best_seq]
                next_tokens.append(bank_1_best_seq)
                source_indices.append(sources[bank_1_best_seq])
                saved += 1

              del scores[bank_1_best_seq]
              del sources[bank_1_best_seq]

            for sequence in sorted(scores, key=scores.get, reverse=True):
                if sequence[-1] == self.eot:
                    finished[sequence] = scores[sequence]
                else:
                    sum_logprobs[len(next_tokens)] = scores[sequence]
                    next_tokens.append(sequence)
                    source_indices.append(sources[sequence])

                    saved += 1
                    if saved == self.beam_size:
                        break

            finished_sequences.append(finished)

        tokens = torch.tensor(next_tokens, device=tokens.device)
        self.inference.rearrange_kv_cache(source_indices)

        # add newly finished sequences to self.finished_sequences
        assert len(self.finished_sequences) == len(finished_sequences)
        for previously_finished, newly_finished in zip(
            self.finished_sequences, finished_sequences
        ):
            for seq in sorted(newly_finished, key=newly_finished.get, reverse=True):
                if len(previously_finished) >= self.max_candidates:
                    break  # the candidate list is full
                previously_finished[seq] = newly_finished[seq]
        # mark as completed if all audio has enough number of samples
        completed = all(
            len(sequences) >= self.max_candidates
            for sequences in self.finished_sequences
        )

        return tokens, completed

    def finalize(self, preceding_tokens, sum_logprobs):
        # collect all finished sequences, including patience, and add unfinished ones if not enough
        """
        TODO: Add new code (or copy existing finalize code) here to implement constrained beam search
        Refer to https://github.com/openai/whisper/blob/main/whisper/decoding.py#L301-L404 for the original finalize function
        """
        sum_logprobs = sum_logprobs.cpu()
        for i, sequences in enumerate(self.finished_sequences):
            if (
                len(sequences) < self.beam_size
            ):  # when not enough sequences are finished
                for j in list(np.argsort(sum_logprobs[i]))[::-1]:
                    sequence = preceding_tokens[i, j].tolist() + [self.eot]
                    sequences[tuple(sequence)] = sum_logprobs[i][j].item()
                    if len(sequences) >= self.beam_size:
                        break

        tokens: List[List[Tensor]] = [
            [torch.tensor(seq) for seq in sequences.keys()]
            for sequences in self.finished_sequences
        ]
        sum_logprobs: List[List[float]] = [
            list(sequences.values()) for sequences in self.finished_sequences
        ]
        return tokens, sum_logprobs

class CustomDecodingTask(DecodingTask):
    """
    Updates the existing `DecodingTask` class form whisper to use constrained beam search
    """
    def __init__(self, model: "Whisper", options: DecodingOptions):
        options = replace(options, beam_size = 2 * options.beam_size if options.beam_size is not None else None)
        super().__init__(model, options)
        self.decoder = CustomBeamSearchDecoder(
            self.options.beam_size, self.tokenizer.eot, self.inference, self.options.patience
        )

@torch.no_grad()
def custom_decode(
    model: torch.nn.Module,
    mel: torch.Tensor,
    options: DecodingOptions = DecodingOptions(),
    **kwargs,
) -> Union[DecodingResult, List[DecodingResult]]:
    """
    decode function to perform constrained beam search decoding
    """
    single = mel.ndim
    if single == 2:
        mel = mel.unsqueeze(0)

    if kwargs:
        options = replace(options, **kwargs)

    result = CustomDecodingTask(model, options).run(mel)

    return result[0] if single else result

# %%
def inferencer(json_file_path, model, dataset, beam_size):
    """
    Perform inference on every example within `dataset` using `model` and save it in `json_file_path`.
    """

    predictions = []
    ground_truths = []
    to_json = []
    for item in tqdm.tqdm(dataset):
        ground_truth = item['transcription']
        prediction = custom_transcribe(model=model, audio = torch.tensor(item['audio']['array'].astype(np.float32)), language="hi", beam_size=beam_size)['text']

        ground_truths.append(ground_truth)
        predictions.append(prediction)

        to_json.append({
            'id': item['id'],
            'ground_truth': ground_truth,
            'prediction': prediction
        })

    cer_ = cer.compute(predictions=predictions, references=ground_truths)
    wer_ = wer.compute(predictions=predictions, references=ground_truths)

    to_json = [{'cer':cer_, 'wer': wer_}] + to_json

    # Write updated data back to JSON file
    with open(json_file_path, 'w') as json_file:
        json.dump(to_json, json_file, indent=4)

# %%
model = whisper.load_model("/content/whisper-small-finetuned.pt")
json_file_path = "./fine_tuned_whisper_with_constrained_beam_search.json"
inferencer(json_file_path, model, dataset['test'], beam_size=3)
# Out:
# 100%|██████████| 61/61 [05:23<00:00,  5.30s/it]

# %%
# !head -n 5 ./fine_tuned_whisper_with_constrained_beam_search.json
# Out:
# [
#     {
#         "cer": 0.6888107333593851,
#         "wer": 0.8829724985371562
#     },
